# %% [markdown]
# #UNIVARIATE ANALYSIS
# COUNTPLOT = DIRECTLY= CATEGORICAL COLUMN
# PIE CHART, BAR CHART = CATEGORICAL COLUMN = VALUE COUNTS
# NUMERICAL COLUMN = BOXPLOT, HISTOGRAM
#
#
# #PIE CHART IS ONLY AVAILABLE ON MATPLOT
#
#
# #BIVARIATE ANALYSIS
# PIECHART, BARGRAPH = GROUPING  = CATEGORICAL, NUMERICAL
# LINE CHART, STRIP PLOT, KDE PLOT, POINT PLOT, BOXPLOT = CATEGORICAL, NUMERICAL
# SCATTER PLOT = x ANF y BOTH SHOULD BE NUMERICAL
#
#
#
# #MULTIVARIATE ANALYSIS
# HEAT MAP = AFTER FINDING CORRELATION AND PIVOT

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("D:\\ARBOR_ACADEMY\\Python_Online\\Project\\bank_data_clean.csv")

# %%
df
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45156  51.0   60000      825   married      yes      no      no   no
# 45157  71.0   55000     1729  divorced      yes      no      no   no
# 45158  72.0   55000     5715   married      yes      no      no   no
# 45159  57.0   20000      668   married      yes      no      no   no
# 45160  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month   duration  campaign  pdays  previous  \
# ...

# %%
print(df.columns)
# Out:
# Index(['age', 'salary', 'balance', 'marital', 'targeted', 'default', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'response', 'job', 'education'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age         salary        balance           day      duration  \
# count  45161.000000   45161.000000   45161.000000  45161.000000  45161.000000
# mean      40.935763   57004.849317    1362.850690     15.807024      4.302774
# std       10.618790   32087.698810    3045.939589      8.322754      4.293129
# min       18.000000       0.000000   -8019.000000      1.000000      0.000000
# 25%       33.000000   20000.000000      72.000000      8.000000      1.716667
# 50%       39.000000   60000.000000     448.000000     16.000000      3.000000
# 75%       48.000000   70000.000000    1428.000000     21.000000      5.316667
# max       95.000000  120000.000000  102127.000000     31.000000     81.966667
#
#            campaign        pdays      previous
# count  45161.000000  8246.000000  45161.000000
# mean       2.763358   224.542202      0.580014
# std        3.096964   115.210792      2.303563
# min        1.000000     1.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45161 entries, 0 to 45160
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45161 non-null  float64
#  1   salary     45161 non-null  int64
#  2   balance    45161 non-null  int64
#  3   marital    45161 non-null  object
#  4   targeted   45161 non-null  object
#  5   default    45161 non-null  object
#  6   housing    45161 non-null  object
#  7   loan       45161 non-null  object
#  8   contact    45161 non-null  object
#  9   day        45161 non-null  int64
#  10  month      45161 non-null  object
#  11  duration   45161 non-null  float64
#  12  campaign   45161 non-null  int64
#  13  pdays      8246 non-null   float64
#  14  previous   45161 non-null  int64
#  15  poutcome   45161 non-null  object
#  16  response   45161 non-null  object
#  17  job        45161 non-null  object
#  18  education  45161 non-null  object
# ...

# %%
plt.figure(figsize= [10, 4])
sns.histplot(data= df, x= 'salary', bins=15)
plt.show()

# %%
sns.boxplot(x= df.age)
plt.show()

# %% [markdown]
# MARITAL STSTUS

# %%
df.marital.value_counts(normalize= True)
# Out:
# marital
# married     0.601957
# single      0.282943
# divorced    0.115099
# Name: proportion, dtype: float64

# %%
sns.barplot(df.marital.value_counts(normalize= True))
plt.show()

# %% [markdown]
# JOB

# %%
df.job.value_counts(normalize= True)
# Out:
# job
# blue-collar      0.215274
# management       0.209273
# technician       0.168043
# admin.           0.114369
# services         0.091849
# retired          0.050087
# self-employed    0.034853
# entrepreneur     0.032860
# unemployed       0.028830
# housemaid        0.027413
# student          0.020770
# unknown          0.006377
# Name: proportion, dtype: float64

# %%
sns.barplot(df.job.value_counts(normalize= True))
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# EDUCATION

# %%
df.education.value_counts(normalize= True)
# Out:
# education
# secondary    0.513275
# tertiary     0.294192
# primary      0.151436
# unknown      0.041097
# Name: proportion, dtype: float64

# %%
sns.barplot(df.education.value_counts(normalize= True))
# Out:
# <Axes: xlabel='education', ylabel='proportion'>

# %%
e = [0, 0, 0.3, 0.7]

color = ['r', 'b', 'g', 'y']
df.education.value_counts(normalize= True).plot.pie(autopct= '%1.2f%%', shadow= True, explode=e, colors=color)
# Out:
# <Axes: ylabel='proportion'>

# %%
df.response.value_counts(normalize=True)
# Out:
# response
# no     0.882974
# yes    0.117026
# Name: proportion, dtype: float64

# %%
sns.barplot(df.response.value_counts(normalize=True))
# Out:
# <Axes: xlabel='response', ylabel='proportion'>

# %%
df.response.value_counts(normalize=True).plot.bar()
plt.show()

# %%
sns.scatterplot(data=df, x= 'salary', y= 'balance', hue= 'marital')
# Out:
# <Axes: xlabel='salary', ylabel='balance'>

# %%
df.plot.scatter(x= 'age', y= 'balance')
# Out:
# <Axes: xlabel='age', ylabel='balance'>

# %% [markdown]
# # WE TRIED TO GIAN INSIGHT, BUT DON'T SEE ANY AS OF NOW.

# %%
correl = df[['age', 'balance', 'salary']].corr()
print(correl)


sns.heatmap(correl, annot=True, cmap= 'YlGnBu')
plt.show()
# Out:
#               age   balance    salary
# age      1.000000  0.097710  0.024513
# balance  0.097710  1.000000  0.055489
# salary   0.024513  0.055489  1.000000

# %% [markdown]
# # salary v/s response

# %%
df.groupby('response')['salary'].mean()
# Out:
# response
# no     56769.510482
# yes    58780.510880
# Name: salary, dtype: float64

# %%
sns.boxplot(data= df, x= 'response', y= 'salary')   #yes means loan taken by customers
plt.show()                                          #no means loan not taken by customers

# %%
df.groupby('response')['salary'].median()
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %% [markdown]
# EDUCATION V/S MARITAL V/S RESPONSE

# %%
res= pd.pivot_table(data= df, index= 'education', columns= 'marital', values= 'response', aggfunc='count')
res
# Out:
# marital    divorced  married  single
# education
# primary         749     5238     852
# secondary      2810    13756    6614
# tertiary       1470     7032    4784
# unknown         169     1159     528
